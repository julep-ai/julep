# %%
from memory.cozo import client
from memory.embed import embed

# %%
text = "What is Diwank like as a person?"
[query_embedding] = embed([text], "query")

n = 100
confidence = 0.5
radius = 1 - confidence

# Embedding search

# query = f"""
# ?[belief, valence, dist, character_id, aspects] := ~beliefs:embedding_space{{ aspects, belief, valence, character_id |
#     query: vec({query_embedding}),
#     k: {n},
#     ef: 20,
#     radius: {radius},
#     bind_distance: dist,
# }}

# :order -valence
# :order dist
# """

keywords = "Diwank person like"
query = f"""
?[belief, valence, score, character_id] := ~beliefs:summary {{ belief, valence, character_id |
    query: "{keywords}",
    k: {n},
    score_kind: 'tf_idf',
    bind_score: score
}}

:order -valence
:order -score
:limit {n}
"""


client.run(query)
# Out:
#                                                belief  valence      score  \
# 0   - At their core, Diwank is driven by innovativ...      3.0  35.918096
# 1   Pascal was the first person from Silicon Valle...      3.0   4.449413
# 2   Diwank's mom's name is Shikha Singh. She is an...      3.0   3.019018
# 3   Diwank believes in autonomy, independence, and...      2.0   5.243724
# 4   Diwank values humility, open-mindedness, and p...      2.0   5.243724
# 5   At their core, Diwank is composed and adaptabl...      2.0   4.449413
# 6   Diwank is moderately nurturing, helpful, empat...      1.0   8.025399
# 7   Diwank believes in debating and fighting for t...      1.0   7.231088
# 8   Diwank exhibits strong leadership skills, taki...      1.0   7.231088
# 9   Diwank has an interest in understanding people...      1.0   7.231088
# 10  Diwank is extraverted, gregarious, engaging, a...      1.0   7.231088
# 11  Diwank is humorous, tending to be more joyful ...      1.0   7.231088
# 12  Diwank is tough, feisty, critical, and direct ...      1.0   7.231088
# 13  Diwank likes intimate settings but is comforta...      1.0   7.231088
# 14  Diwank believes that having a funny person in ...      1.0   3.098132
# 15  Diwank is open to changing or developing aspec...      1.0   3.098132
# 16  Diwank tends to respond thoughtfully and respe...      1.0   3.098132
# 17  Diwank admires people with clear and logical a...      1.0   2.303820
# 18  Diwank assumes personal accountability for suc...      1.0   2.303820
# 19  Diwank believes in testing their thinking with...      1.0   2.303820
# 20  Diwank believes that people look to them for e...      1.0   2.303820
# 21  Diwank believes they have a somewhat assertive...      1.0   2.303820
# 22  Diwank considers themselves to be a light-hear...      1.0   2.303820
# 23  Diwank finds people who don't take risks somew...      1.0   2.303820
# 24  Diwank has experienced mild obsession with cer...      1.0   2.303820
# 25  Diwank is a self-starter and agrees with this ...      1.0   2.303820
# 26  Diwank is comfortable adapting their personali...      1.0   2.303820
# 27  Diwank is determined to overcome obstacles for...      1.0   2.303820
# 28  Diwank is fascinated by exotic destinations an...      1.0   2.303820
# 29  Diwank is neutral about the importance of bein...      1.0   2.303820
# 30  Diwank is not a strong perfectionist and mildl...      1.0   2.303820
# 31  Diwank is often the first one to take the rein...      1.0   2.303820
# 32  Diwank likes discussing abstract ideas and dis...      1.0   2.303820
# 33  Diwank likes to impress others and be successf...      1.0   2.303820
# 34  Diwank mildly agrees that they are a highly en...      1.0   2.303820
# 35  Diwank mildly agrees with being an anti-establ...      1.0   2.303820
# 36  Diwank often sets motivating goals for their t...      1.0   2.303820
# 37  Diwank often worries about criticism hurting p...      1.0   2.303820
# 38  Diwank sometimes feels sluggish and unmotivate...      1.0   2.303820
# 39  Diwank strongly believes that they have signif...      1.0   2.303820
# 40  Diwank's perfectionism does not significantly ...      1.0   2.303820
# 41  Others seek out Diwank for advice on personal ...      1.0   2.303820
# 42  Diwank believes they have no difficulty contro...      1.0   1.509509
# 43       Diwank enjoys projects with clear direction.      1.0   1.509509
# 44  Diwank feels mildly satisfied with gaining new...      1.0   1.509509
# 45   Diwank is considered a good motivator by others.      1.0   1.509509
# 46         Diwank is mildly systematic in their work.      1.0   1.509509
# 47  Diwank is not easily discouraged, mildly disag...      1.0   1.509509
# 48  Diwank is often the life of the party to a mil...      1.0   1.509509
# 49  Diwank mildly agrees with acting differently i...      1.0   1.509509
# 50  Diwank mildly believes that hard work can lead...      1.0   1.509509
# 51  Diwank mildly disagrees with being deeply moti...      1.0   1.509509
# 52   Diwank mildly likes receiving critical feedback.      1.0   1.509509
# 53       Diwank often prioritizes work over pleasure.      1.0   1.509509
# 54  Diwank readily notices the habits and quirks o...      1.0   1.509509
# 55  Diwank seeks a deeper meaning in things natura...      1.0   1.509509
# 56                            Diwank seeks adventure.      1.0   1.509509
#
#                             character_id aspects
# 0   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 1   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 2   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 3   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 4   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 5   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 6   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 7   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 8   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 9   d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 10  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 11  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 12  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 13  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 14  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 15  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 16  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 17  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 18  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 19  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 20  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 21  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 22  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 23  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 24  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 25  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 26  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 27  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 28  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 29  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 30  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 31  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 32  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 33  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 34  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 35  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 36  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 37  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 38  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 39  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 40  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 41  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 42  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 43  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 44  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 45  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 46  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 47  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 48  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 49  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 50  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 51  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 52  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 53  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 54  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 55  d5f6a824-efbd-4945-b267-d9cd12cada77      []
# 56  d5f6a824-efbd-4945-b267-d9cd12cada77      []

# %%
client.close()
