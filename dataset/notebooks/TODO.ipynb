# %% [markdown]
# ### SFT
#
# - [x] [[#ready](#)] [[#sft](#)] [gpt_roleplay_realm](https://huggingface.co/datasets/IlyaGusev/gpt_roleplay_realm)
# - [x] [[#ready](#)] [[#non-anthro](#)] [[#sft](#)] [chatalpaca-20k](https://github.com/cascip/ChatAlpaca/blob/main/data/chatalpaca-20k.json)
# - [x] [[#ready](#)] [[#sft](#)] [coqa](https://huggingface.co/datasets/coqa/)
# - [x] [[#needs-processing](#)] [[#sft](#)] [ambig_qa](https://huggingface.co/datasets/ambig_qa)
# - [x] [[#needs-processing](#)] [[#sft](#)] [daily_dialog](https://huggingface.co/datasets/daily_dialog)
# - [x] [[#needs-processing](#)] [[#restricted](#)] [[#sft](#)] [bluemoon-roleplay](https://huggingface.co/datasets/Squish42/bluemoon-fandom-1-1-rp-cleaned)
# - [x] [[#self-instruct](#)] [[#sft](#)] [orca_minis_uncensored_dataset](https://huggingface.co/datasets/psmathur/orca_minis_uncensored_dataset)
#
# ### TODOs
#
# - [x] [[#todo](#)] separate prompt and loss-making tokens for orca-mini
# - [x] [[#todo](#)] train mpt-30b-chat on orca-mini
# - [x] [[#todo](#)] Remove "toolformer: enabled"
# - [x] [[#todo](#)] join datasets
# - [x] [[#todo](#)] separate prompt and loss-making tokens for combined dataset
# - [ ] [[#todo](#)] train mpt-30b-chat on combined dataset
#
# ### 7b todos
#
# - [ ] [[#todo](#)] set <|im_start|> to same embedding as bos + average (on xgen)
# - [ ] [[#todo](#)] set <|im_end|> with the same embedding as average of all tokens (on xgen)
# - [ ] [[#todo](#)] train xgen-7b
# - [ ] [[#todo](#)] classic fiction to play dialog
# - [ ] [[#todo](#)] create textbooks dataset
#
# ### Benchmark
#
# **Pre-RLHF**
# - [ ] [[#benchmark](#)] [opencompass](https://github.com/InternLM/opencompass)
# - [ ] [[#benchmark](#)] [lm-evaluation-harness](https://github.com/EleutherAI/lm-evaluation-harness/)
#
# **Post-RLHF**
# - [ ] [[#benchmark](#)] [alignscore](https://github.com/yuh-zha/AlignScore)
# - [ ] [[#benchmark](#)] [alpaca_eval](https://github.com/tatsu-lab/alpaca_eval/tree/main#making-a-new-evaluator) benchmark
#
#
# ### Postponed TODOs
#
# - [ ] [[#todo](#)] Add control section
# - [ ] [[#todo](#)] Add control tokens with embeddings to tokenizer
# - [ ] [[#todo](#)] add preamble to control section (this is loss-producing) but the control tokens section is NOT loss-producing
# - [ ] [[#todo](#)] add instructions like, keep it conversational. write small outputs. give detailed answer
# - [ ] [[#todo](#)] Add I should “think” about this before answering to the prompts for rows with chain of thought turns
#
#
# ### RLHF
#
# - [ ] [[#rlhf](#)] [ethics](https://github.com/hendrycks/ethics)
# - [ ] [[#rlhf](#)] [deberta-v3-large-tasksource-rlhf-reward-model](https://huggingface.co/sileod/deberta-v3-large-tasksource-rlhf-reward-model)
# - [ ] [[#rlhf](#)] use scifact for rlhf
# - [ ] [[#rlhf](#)] [Objectives](https://github.com/examine-ai/Objectives)
# - [ ] [[#rlhf](#)] [alpacafarm](https://github.com/tatsu-lab/alpaca_farm)
# - [ ] [[#rlhf](#)] [curiousreplay](https://github.com/AutonomousAgentsLab/curiousreplay)
# - [ ] [[#rlhf](#)] [neutral-to-flirty](https://huggingface.co/datasets/ieuniversity/neutral_to_flirty)
# - [ ] [[#rlhf](#)] [self-refine](https://github.com/madaan/self-refine)
# - [ ] [[#rlhf](#)] [MOSS](https://github.com/OpenLMLab/MOSS) user prompts for rlhf
#
# ### Postponed
#
# - [ ] [[#self-instruct](#)] [[#sft](#)] [roleplay-instructions-dataset](https://huggingface.co/datasets/iamketan25/roleplay-instructions-dataset)
# - [ ] [[#self-instruct](#)] [[#sft](#)] [gptteacher_role_play-lmgym](https://huggingface.co/datasets/hedronstone/gptteacher_role_play-lmgym)
# - [ ] [[#needs-processing](#)] [[#sft](#)] [schema_guided_dstc8](https://huggingface.co/datasets/schema_guided_dstc8)
# - [ ] [[#needs-processing](#)] [[#sft](#)] [ALCE](https://github.com/princeton-nlp/ALCE) ; citation data
# - [ ] [[#needs-processing](#)] [[#sft](#)] [SAIL](https://huggingface.co/datasets/lukasmoeller/sail_preprocessed) ; search augmented learning dataset
# - [ ] [[#needs-processing](#)] [[#sft](#)] [spoken-conversational-search-dataset](https://github.com/JTrippas/Spoken-Conversational-Search/blob/master/SCSdata_v1.csv)
# - [ ] [[#needs-processing](#)] [[#sft](#)] [quac](https://huggingface.co/datasets/quac)
# - [ ] [[#sft](#)] [roleplay-io](https://huggingface.co/datasets/AlekseyKorshuk/roleplay-io)
# - [ ] [[#sft](#)] [dialogsum](https://huggingface.co/datasets/spencer/dialogsum_reformat)
# - [ ] [[#sft](#)] [camel/physics](https://huggingface.co/datasets/camel-ai/physics)
# - [ ] [[#sft](#)] [camel/ai_society](https://huggingface.co/datasets/camel-ai/ai_society)
# - [ ] [[#sft](#)] [openchat_sharegpt4_dataset](https://huggingface.co/datasets/openchat/openchat_sharegpt4_dataset)
# - [ ] [[#sft](#)] [ccpe](https://github.com/google-research-datasets/ccpe)
# - [ ] [[#sft](#)] [Commonsense-Dialogues](https://github.com/alexa/Commonsense-Dialogues)
# - [ ] [[#sft](#)] [MOSS](https://github.com/OpenLMLab/MOSS/tree/main/SFT_data/conversations/conversation_with_plugins) plugin thought sft
# - [ ] [[#sft](#)] [drop](https://huggingface.co/datasets/drop) -- reasoning over passages
# - [ ] [[#sft](#)] [curiosity-dialogs](https://huggingface.co/datasets/curiosity_dialogs)
